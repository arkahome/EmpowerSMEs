# %%
import sqlite3

# Create a SQL connection to our SQLite database
con = sqlite3.connect("../db.sqlite3")

# %%
import pandas as pd

# %%
pd.read_sql('SELECT * FROM app_pimodel', con = con)
# Out:
#                            model_pk           model_name  \
# 0  de7e49539af446989ee73227456e947a  Telephonic EM Model
# 1  9045414ede2d4d0fa57f9e4379923edf     Missing Modifier
# 2  370f521f588c4f07aac8b8c68425b06c               Test 3
#
#                                          description  \
# 0                               Telephonic EM Models
# 1  Therapy Codes are missing modifier of GO, GP, GE.
# 2                                              dqdas
#
#                              tags             last_updated_on last_updated_by  \
# 0                   EM,Telephonic  2021-12-19 11:18:18.504697        arkahome
# 1  therapy_codes,missing_modifier  2021-12-19 15:26:12.261052        arkahome
# 2                          sad,hh  2021-12-19 15:48:46.663095        arkahome
#
#   insourcing_or_not insourcing_code deployed_yes_or_no deployed_on  \
# 0                No            None               None        None
# ...

# %%
pd.read_sql('SELECT * FROM app_piSUBmodel', con = con)
# Out:
#                         model_pk_id                      sub_model_pk  \
# 0  de7e49539af446989ee73227456e947a  06910af34aaf491082d785845814f519
# 1  de7e49539af446989ee73227456e947a  393bf655d7534ceaa2db3a19b97e16e3
# 2  9045414ede2d4d0fa57f9e4379923edf  f3b23bffa49543de9ab7f2fc7fdb5e49
#
#   sub_model_name sub_model_description code_type  \
# 0         rule 3           rule 3 desc       sql
# 1         Rule 5        This is rule 5       sql
# 2  For Market CA   For the State of CA       sql
#
#                                            code opportunity_size  \
# 0                   select * from \r\nbla_bla_2             None
# 1                         select * from bla bla             None
# 2  select * from table\r\nwhere\r\nstate = "CA"             None
#
#   insourcing_overlap_perc insourcing_comm_saved  \
# 0                    None                  None
# 1                    None                  None
# 2                    None                  None
#
# ...
